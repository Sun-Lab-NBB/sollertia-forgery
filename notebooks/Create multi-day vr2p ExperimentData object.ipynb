# %% [markdown]
# # Create multi-day vr2p ExperimentData object
# Example notebook of processing multiday suite2p information into a vr2p zarr file.

# %% [markdown]
# ## Load general settings file.
# Select the general settings file that contains the processing parameters

# %%
from pathlib import Path
import sl_shared_assets as sass

sd = sass.SessionData('TycheTest', 'A7', '2022-02-01-16-50-44-000000', 'Experiment', 'null')
sd = sd.load(Path('/data/sun_data/Tyche/A7/2022-02-01-16-50-44-000000'), False)

# %%
# %load_ext autoreload
# %autoreload 2
from vr2p.settings import parse_settings, parse_data_info, select_settings_file

fc_settings = select_settings_file()
# Out:
# FileChooser(path='/home/cornell/Desktop/Kushaan/projects/suite2pOptimized/sl-forgery/notebooks', filename='', …

# %%
settings = parse_settings(fc_settings.selected)

# %% [markdown]
# ## Load animal data info file.
# Select settings file that contains the animal and data info.

# %%
fc_data = select_settings_file(fc_settings.selected_path)
# Out:
# FileChooser(path='/home/cornell/Desktop/Kushaan/projects/suite2pOptimized/sl-forgery/config', filename='', tit…

# %%
data_info = parse_data_info(fc_data.selected)

# %% [markdown]
# ## Process files

# %%
from vr2p.io import process_session_data

process_session_data(data_info, settings, [sd])
# Out:
# Removing previous data at Results/vr2p.zarr
# Processing session: 100%|██████████| 1/1 [00:04<00:00,  4.66s/it]

# %% [markdown]
# ---
