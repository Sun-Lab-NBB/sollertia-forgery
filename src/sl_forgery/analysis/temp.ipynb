# %%
from yaml_dataclass import BehaviorData
from pathlib import Path

data = BehaviorData(root_path="root")

# %%
data.resolve_paths(Path("root_dir"))

# %%
data.behavior_path
# Out:
# WindowsPath('root_dir/behavior_at_frame.feather')
